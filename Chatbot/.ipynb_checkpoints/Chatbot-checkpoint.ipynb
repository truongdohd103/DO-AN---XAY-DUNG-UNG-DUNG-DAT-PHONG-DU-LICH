# %%
# !pip install -U firebase-admin langchain-community langchain-google-genai langchain-chroma langchain langgraph tavily-python langchain-huggingface langchain-tavily chromadb gradio
# Out:
# Collecting firebase-admin
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Admin\anaconda3\Lib\site-packages\~hromadb_rust_bindings'.
#   You can safely remove it manually.
#   Downloading firebase_admin-7.1.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: langchain-community in c:\users\admin\anaconda3\lib\site-packages (0.4)
# Requirement already satisfied: langchain-google-genai in c:\users\admin\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: langchain-chroma in c:\users\admin\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: langchain in c:\users\admin\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: langgraph in c:\users\admin\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: tavily-python in c:\users\admin\anaconda3\lib\site-packages (0.7.12)
# Requirement already satisfied: langchain-huggingface in c:\users\admin\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: langchain-tavily in c:\users\admin\anaconda3\lib\site-packages (0.2.12)
# Requirement already satisfied: chromadb in c:\users\admin\anaconda3\lib\site-packages (1.1.1)
# Collecting chromadb
#   Downloading chromadb-1.2.0-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: gradio in c:\users\admin\anaconda3\lib\site-packages (5.49.1)
# Collecting cachecontrol>=0.14.3 (from firebase-admin)
#   Downloading cachecontrol-0.14.3-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.25.1 in c:\users\admin\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.26.0)
# Collecting google-cloud-firestore>=2.21.0 (from firebase-admin)
#   Downloading google_cloud_firestore-2.21.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting google-cloud-storage>=3.1.1 (from firebase-admin)
#   Downloading google_cloud_storage-3.4.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\admin\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->firebase-admin) (2.10.1)
# Requirement already satisfied: httpx==0.28.1 in c:\users\admin\anaconda3\lib\site-packages (from httpx[http2]==0.28.1->firebase-admin) (0.28.1)
# Requirement already satisfied: anyio in c:\users\admin\anaconda3\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (4.7.0)
# Requirement already satisfied: certifi in c:\users\admin\anaconda3\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\anaconda3\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (1.0.9)
# Requirement already satisfied: idna in c:\users\admin\anaconda3\lib\site-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (3.7)
# Collecting h2<5,>=3 (from httpx[http2]==0.28.1->firebase-admin)
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\admin\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\admin\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (6.33.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\admin\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\admin\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.41.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\admin\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\admin\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.75.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\admin\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (1.75.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\admin\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\admin\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (4.9.1)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\admin\anaconda3\lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (4.12.2)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: h11>=0.16 in c:\users\admin\anaconda3\lib\site-packages (from httpcore==1.*->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\admin\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=2.25.1->google-api-core[grpc]<3.0.0dev,>=2.25.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (2.0.39)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (3.13.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (2.11.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (0.4.37)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\admin\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\admin\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-community) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\admin\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-community) (2.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.27.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\admin\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\admin\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: google-ai-generativelanguage<1.0.0,>=0.7.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-google-genai) (0.8.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\admin\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.37.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (1.23.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (0.19.2)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\admin\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\admin\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\admin\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\admin\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in c:\users\admin\anaconda3\lib\site-packages (from langgraph) (2.1.2)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from langgraph) (1.0.0)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\admin\anaconda3\lib\site-packages (from langgraph) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\admin\anaconda3\lib\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\admin\anaconda3\lib\site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph) (1.11.0)
# Requirement already satisfied: tiktoken>=0.5.1 in c:\users\admin\anaconda3\lib\site-packages (from tavily-python) (0.12.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.33.4 in c:\users\admin\anaconda3\lib\site-packages (from langchain-huggingface) (0.35.3)
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2025.3.2)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: audioop-lts<1.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.119.0)
# Requirement already satisfied: ffmpy in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.6.3)
# Requirement already satisfied: gradio-client==1.13.3 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: jinja2<4.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydub in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.14.1)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.48.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: websockets<16.0,>=13.0 in c:\users\admin\anaconda3\lib\site-packages (from gradio-client==1.13.3->gradio) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\admin\anaconda3\lib\site-packages (from anyio->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\admin\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\admin\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.0)
# Requirement already satisfied: pyproject_hooks in c:\users\admin\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in c:\users\admin\anaconda3\lib\site-packages (from cachecontrol>=0.14.3->firebase-admin) (1.0.3)
# Collecting google-cloud-core<3.0.0,>=1.4.1 (from google-cloud-firestore>=2.21.0->firebase-admin)
#   Downloading google_cloud_core-2.4.3-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media<3.0.0,>=2.7.2 (from google-cloud-storage>=3.1.1->firebase-admin)
#   Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-crc32c<2.0.0,>=1.1.3 (from google-cloud-storage>=3.1.1->firebase-admin)
#   Downloading google_crc32c-1.7.1-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\admin\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\admin\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\admin\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: coloredlogs in c:\users\admin\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\admin\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: sympy in c:\users\admin\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\admin\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\admin\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\admin\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\admin\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\admin\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.59b0)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\admin\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->firebase-admin) (44.0.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\admin\anaconda3\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase-admin) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->firebase-admin) (2.21)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\admin\anaconda3\lib\site-packages (from tiktoken>=0.5.1->tavily-python) (2024.11.6)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\admin\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\admin\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\admin\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\admin\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\admin\anaconda3\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Downloading firebase_admin-7.1.0-py3-none-any.whl (137 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading chromadb-1.2.0-cp39-abi3-win_amd64.whl (20.3 MB)
#    ---------------------------------------- 0.0/20.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/20.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/20.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/20.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/20.3 MB 939.1 kB/s eta 0:00:22
#    - -------------------------------------- 0.8/20.3 MB 1.1 MB/s eta 0:00:19
#    -- ------------------------------------- 1.0/20.3 MB 1.2 MB/s eta 0:00:17
#    --- ------------------------------------ 1.6/20.3 MB 1.3 MB/s eta 0:00:15
#    --- ------------------------------------ 1.8/20.3 MB 1.4 MB/s eta 0:00:14
#    ---- ----------------------------------- 2.4/20.3 MB 1.5 MB/s eta 0:00:12
#    ----- ---------------------------------- 2.9/20.3 MB 1.6 MB/s eta 0:00:11
#    ------ --------------------------------- 3.4/20.3 MB 1.7 MB/s eta 0:00:10
#    ------- -------------------------------- 3.9/20.3 MB 1.8 MB/s eta 0:00:09
#    --------- ------------------------------ 4.7/20.3 MB 2.0 MB/s eta 0:00:08
#    ---------- ----------------------------- 5.5/20.3 MB 2.1 MB/s eta 0:00:07
#    ------------ --------------------------- 6.3/20.3 MB 2.2 MB/s eta 0:00:07
#    -------------- ------------------------- 7.3/20.3 MB 2.4 MB/s eta 0:00:06
#    ---------------- ----------------------- 8.1/20.3 MB 2.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 8.9/20.3 MB 2.6 MB/s eta 0:00:05
#    ------------------- -------------------- 10.0/20.3 MB 2.7 MB/s eta 0:00:04
#    --------------------- ------------------ 10.7/20.3 MB 2.8 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.8/20.3 MB 2.9 MB/s eta 0:00:03
#    ------------------------- -------------- 12.8/20.3 MB 3.0 MB/s eta 0:00:03
#    -------------------------- ------------- 13.6/20.3 MB 3.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 14.4/20.3 MB 3.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 15.2/20.3 MB 3.1 MB/s eta 0:00:02
#    -------------------------------- ------- 16.3/20.3 MB 3.1 MB/s eta 0:00:02
#    -------------------------------- ------- 16.5/20.3 MB 3.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 18.1/20.3 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 19.1/20.3 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  20.2/20.3 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 20.3/20.3 MB 3.3 MB/s  0:00:06
# Downloading cachecontrol-0.14.3-py3-none-any.whl (21 kB)
# Downloading google_cloud_firestore-2.21.0-py3-none-any.whl (368 kB)
# Downloading google_cloud_core-2.4.3-py2.py3-none-any.whl (29 kB)
# Downloading google_cloud_storage-3.4.1-py3-none-any.whl (290 kB)
# Downloading google_crc32c-1.7.1-cp313-cp313-win_amd64.whl (33 kB)
# Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
# Installing collected packages: hyperframe, hpack, google-crc32c, h2, google-resumable-media, cachecontrol, google-cloud-core, google-cloud-storage, google-cloud-firestore, firebase-admin, chromadb
#
#    ------- --------------------------------  2/11 [google-crc32c]
#    -------------- -------------------------  4/11 [google-resumable-media]
#    ------------------ ---------------------  5/11 [cachecontrol]
#    ------------------------- --------------  7/11 [google-cloud-storage]
#    ------------------------- --------------  7/11 [google-cloud-storage]
#    ------------------------- --------------  7/11 [google-cloud-storage]
#    ----------------------------- ----------  8/11 [google-cloud-firestore]
#    ----------------------------- ----------  8/11 [google-cloud-firestore]
#    ----------------------------- ----------  8/11 [google-cloud-firestore]
#    ----------------------------- ----------  8/11 [google-cloud-firestore]
#    -------------------------------- -------  9/11 [firebase-admin]
#    -------------------------------- -------  9/11 [firebase-admin]
#    -------------------------------- -------  9/11 [firebase-admin]
#    -------------------------------- -------  9/11 [firebase-admin]
#    -------------------------------- -------  9/11 [firebase-admin]
#   Attempting uninstall: chromadb
#    -------------------------------- -------  9/11 [firebase-admin]
#     Found existing installation: chromadb 1.1.1
#    -------------------------------- -------  9/11 [firebase-admin]
#    ------------------------------------ --- 10/11 [chromadb]
#     Uninstalling chromadb-1.1.1:
#    ------------------------------------ --- 10/11 [chromadb]
#       Successfully uninstalled chromadb-1.1.1
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ------------------------------------ --- 10/11 [chromadb]
#    ---------------------------------------- 11/11 [chromadb]
#
# Successfully installed cachecontrol-0.14.3 chromadb-1.2.0 firebase-admin-7.1.0 google-cloud-core-2.4.3 google-cloud-firestore-2.21.0 google-cloud-storage-3.4.1 google-crc32c-1.7.1 google-resumable-media-2.7.2 h2-4.3.0 hpack-4.1.0 hyperframe-6.1.0

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from pydantic import BaseModel, Field

# %%
import os
import getpass

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter API key:")

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
    max_tokens=None,
)

# %%
from langchain_core.documents import Document

# %%
documents = []
for filename in os.listdir():
  if filename.endswith('.txt'):
    with open(filename, 'r', encoding='utf-8') as file:
      content = file.read()
      documents.append(
          Document(
              page_content=content,
              metadata= {
                  'source': filename
              }
          )
      )

# %%
documents[0]
# Out:
# Document(metadata={'source': 'TÀI LIỆU HƯỚNG DẪN APP CHILLSTAY.txt'}, page_content='================================================================================\nTÀI LIỆU HƯỚNG DẪN SỬ DỤNG ỨNG DỤNG CHILSTAY\nHệ thống đặt phòng khách sạn, homestay, căn hộ du lịch\n================================================================================\n\nMỤC LỤC\n1. Giới thiệu ứng dụng\n2. Quản lý tài khoản\n3. Tìm kiếm và đặt phòng\n4. Quản lý đặt phòng\n5. Tính năng khác\n6. Xử lý lỗi thường gặp\n\n================================================================================\n1. GIỚI THIỆU ỨNG DỤNG CHILSTAY\n================================================================================\n\nChilstay là ứng dụng đặt phòng du lịch giúp bạn:\n- Tìm kiếm chỗ ở (khách sạn, homestay, căn hộ) theo địa điểm và sở thích\n- Đặt phòng trực tuyến với thanh toán an toàn\n- Quản lý lịch sử đặt phòng và các chuyến đi\n- Đánh giá và chia sẻ trải nghiệm lưu trú\n- Nhận ưu đãi và khuyến mãi hấp dẫn\n\n================================================================================\n2. QUẢN LÝ TÀI KHOẢN\n================================================================================\n\n2.1. ĐĂNG KÝ TÀI KHOẢN MỚI\n--------------------------------------------------------------------------------\n\nCÁCH ĐĂNG KÝ:\n\nBước 1: Chọn phương thức đăng ký\n- Mở ứng dụng và chọn "Đăng ký"\n- Chọn một trong các phương thức:\n  + Đăng ký bằng Gmail\n  + Đăng ký bằng Facebook\n  + Đăng ký bằng Email và mật khẩu\n\nBước 2: Nhập thông tin (nếu chọn đăng ký bằng Email)\n- Email: Nhập địa chỉ email hợp lệ\n- Mật khẩu: Tối thiểu 8 ký tự, bao gồm chữ hoa, chữ thường và số\n- Xác nhận mật khẩu: Nhập lại mật khẩu để xác nhận\n\nBước 3: Xác thực OTP\n- Hệ thống sẽ gửi mã OTP (6 chữ số) đến email của bạn\n- Nhập mã OTP vào ô xác nhận\n- Nếu không nhận được mã, bạn có thể chọn "Gửi lại mã"\n\nBước 4: Hoàn tất\n- Sau khi xác nhận OTP thành công, tài khoản của bạn đã được tạo\n- Bạn có thể đăng nhập và bắt đầu sử dụng\n\nLƯU Ý:\n✓ Email đã đăng ký không thể sử dụng lại cho tài khoản khác\n✓ Mật khẩu mạnh giúp bảo vệ tài khoản tốt hơn\n✓ Mã OTP có hiệu lực trong 5 phút\n\n--------------------------------------------------------------------------------\n\n2.2. ĐĂNG NHẬP\n--------------------------------------------------------------------------------\n\nCÁCH ĐĂNG NHẬP:\n\nBước 1: Mở ứng dụng và chọn "Đăng nhập"\n\nBước 2: Nhập thông tin đăng nhập\n- Email: Địa chỉ email bạn đã đăng ký\n- Mật khẩu: Mật khẩu tài khoản\n\nBước 3: Chọn "Đăng nhập"\n- Hệ thống sẽ xác thực và đưa bạn vào trang chủ\n\nLƯU Ý:\n✓ Nếu quên mật khẩu, chọn "Quên mật khẩu?" để đặt lại\n✓ Tài khoản bị khóa do vi phạm? Liên hệ bộ phận hỗ trợ\n\n--------------------------------------------------------------------------------\n\n2.3. QUÊN MẬT KHẨU\n--------------------------------------------------------------------------------\n\nCÁCH ĐẶT LẠI MẬT KHẨU:\n\nBước 1: Tại màn hình đăng nhập, chọn "Quên mật khẩu?"\n\nBước 2: Nhập email đã đăng ký\n- Nhập địa chỉ email tài khoản của bạn\n- Chọn "Gửi mã xác nhận"\n\nBước 3: Xác thực OTP\n- Kiểm tra email và nhập mã OTP\n- Mã OTP có hiệu lực trong 5 phút\n\nBước 4: Tạo mật khẩu mới\n- Nhập mật khẩu mới (tối thiểu 8 ký tự, có chữ hoa, chữ thường và số)\n- Nhập lại để xác nhận\n- Chọn "Xác nhận"\n\nBước 5: Hoàn tất\n- Mật khẩu đã được đổi thành công\n- Hệ thống tự động đăng nhập bạn vào ứng dụng\n\n--------------------------------------------------------------------------------\n\n2.4. ĐỔI MẬT KHẨU\n--------------------------------------------------------------------------------\n\nCÁCH ĐỔI MẬT KHẨU KHI ĐÃ ĐĂNG NHẬP:\n\nBước 1: Vào trang "Tài khoản" của bạn\n\nBước 2: Chọn "Đổi mật khẩu"\n\nBước 3: Nhập thông tin\n- Mật khẩu mới: Nhập mật khẩu mới\n- Xác nhận mật khẩu: Nhập lại mật khẩu mới\n\nBước 4: Chọn "Xác nhận"\n- Mật khẩu được cập nhật thành công\n\nLƯU Ý:\n✓ Nên đổi mật khẩu định kỳ để bảo mật tài khoản\n✓ Không chia sẻ mật khẩu với người khác\n\n------------ ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1200,
    chunk_overlap=200
)

# %%
all_splits = text_splitter.split_documents(documents)

# %%
all_splits[0]
# Out:
# Document(metadata={'source': 'TÀI LIỆU HƯỚNG DẪN APP CHILLSTAY.txt'}, page_content='================================================================================\nTÀI LIỆU HƯỚNG DẪN SỬ DỤNG ỨNG DỤNG CHILSTAY\nHệ thống đặt phòng khách sạn, homestay, căn hộ du lịch\n================================================================================\n\nMỤC LỤC\n1. Giới thiệu ứng dụng\n2. Quản lý tài khoản\n3. Tìm kiếm và đặt phòng\n4. Quản lý đặt phòng\n5. Tính năng khác\n6. Xử lý lỗi thường gặp\n\n================================================================================\n1. GIỚI THIỆU ỨNG DỤNG CHILSTAY\n================================================================================\n\nChilstay là ứng dụng đặt phòng du lịch giúp bạn:\n- Tìm kiếm chỗ ở (khách sạn, homestay, căn hộ) theo địa điểm và sở thích\n- Đặt phòng trực tuyến với thanh toán an toàn\n- Quản lý lịch sử đặt phòng và các chuyến đi\n- Đánh giá và chia sẻ trải nghiệm lưu trú\n- Nhận ưu đãi và khuyến mãi hấp dẫn\n\n================================================================================\n2. QUẢN LÝ TÀI KHOẢN\n================================================================================\n\n2.1. ĐĂNG KÝ TÀI KHOẢN MỚI\n--------------------------------------------------------------------------------\n\nCÁCH ĐĂNG KÝ:')

# %%
#vector store
from langchain_chroma import Chroma
#vector embedding model
from langchain_huggingface import HuggingFaceEmbeddings

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\admin\anaconda3\lib\site-packages (5.1.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (2.9.0)
# Requirement already satisfied: scikit-learn in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (0.35.3)
# Requirement already satisfied: Pillow in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\admin\anaconda3\lib\site-packages (from sentence-transformers) (4.12.2)
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\admin\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\admin\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\admin\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\admin\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\admin\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\admin\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\admin\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.4.26)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)

# %%
model_name = "sentence-transformers/static-similarity-mrl-multilingual-v1"
model_kwargs = {'device': 'cpu'}
encode_kwargs = {'normalize_embeddings': False}

hf_embedding = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

# %%
vectorstore = Chroma.from_documents(
    documents=all_splits,
    embedding=hf_embedding,
    collection_name="chillstay_docs"
)

# %%
retriver = vectorstore.similarity_search(
    "đăng ký tài khoản", k = 4
)
retriver
# Out:
# [Document(id='599e8a43-bd62-4576-91a9-4c4f47b80fbf', metadata={'source': 'TÀI LIỆU HƯỚNG DẪN APP CHILLSTAY.txt'}, page_content='"Bạn chưa có thông báo nào"\n→ Chưa có thông báo mới\n\n"Bạn chưa có lịch sử đặt phòng"\n→ Chưa từng đặt phòng qua ứng dụng\n\n"Hiện không có cơ sở nào"\n→ Không có kết quả phù hợp, thử thay đổi bộ lọc\n\n"Bạn đã gửi nhiều yêu cầu"\n→ Đợi 10 phút trước khi gửi tin nhắn tiếp\n\n"Nội dung không hợp lệ"\n→ Nội dung có từ ngữ không phù hợp, vui lòng chỉnh sửa\n\n================================================================================\n7. CÂU HỎI THƯỜNG GẶP (FAQ)\n================================================================================\n\n7.1. VỀ TÀI KHOẢN\n--------------------------------------------------------------------------------\n\nQ: Tôi có thể đăng ký nhiều tài khoản bằng một email không?\nA: Không. Mỗi email chỉ đăng ký được một tài khoản duy nhất.\n\nQ: Tôi không nhận được mã OTP thì làm sao?\nA: Kiểm tra hộp thư spam/junk. Nếu vẫn không có, chọn "Gửi lại mã". Lưu ý \n   mã OTP có hiệu lực trong 5 phút.\n\nQ: Tôi có thể đổi email đã đăng ký không?\nA: Hiện tại chưa hỗ trợ đổi email. Bạn có thể tạo tài khoản mới với email khác.\n\nQ: Làm sao để xóa tài khoản?\nA: Vào Tài khoản → Cài đặt → Xóa tài khoản. Hoặc liên hệ bộ phận hỗ trợ.'),
#  Document(id='ece86770-61d8-4e41-9457-9ea1869e6edf', metadata={'source': 'TÀI LIỆU HƯỚNG DẪN APP CHILLSTAY.txt'}, page_content='"Bạn chưa có thông báo nào"\n→ Chưa có thông báo mới\n\n"Bạn chưa có lịch sử đặt phòng"\n→ Chưa từng đặt phòng qua ứng dụng\n\n"Hiện không có cơ sở nào"\n→ Không có kết quả phù hợp, thử thay đổi bộ lọc\n\n"Bạn đã gửi nhiều yêu cầu"\n→ Đợi 10 phút trước khi gửi tin nhắn tiếp\n\n"Nội dung không hợp lệ"\n→ Nội dung có từ ngữ không phù hợp, vui lòng chỉnh sửa\n\n================================================================================\n7. CÂU HỎI THƯỜNG GẶP (FAQ)\n================================================================================\n\n7.1. VỀ TÀI KHOẢN\n--------------------------------------------------------------------------------\n\nQ: Tôi có thể đăng ký nhiều tài khoản bằng một email không?\nA: Không. Mỗi email chỉ đăng ký được một tài khoản duy nhất.\n\nQ: Tôi không nhận được mã OTP thì làm sao?\nA: Kiểm tra hộp thư spam/junk. Nếu vẫn không có, chọn "Gửi lại mã". Lưu ý \n   mã OTP có hiệu lực trong 5 phút.\n\nQ: Tôi có thể đổi email đã đăng ký không?\nA: Hiện tại chưa hỗ trợ đổi email. Bạn có thể tạo tài khoản mới với email khác.\n\nQ: Làm sao để xóa tài khoản?\nA: Vào Tài khoản → Cài đặt → Xóa tài khoản. Hoặc liên hệ bộ phận hỗ trợ.'),
#  Document(id='301182f1-f2c6-42cc-bd67-803b9a54736a', metadata={'source': 'TÀI LIỆU HƯỚNG DẪN APP CHILLSTAY.txt'}, page_content='Q: Làm sao để xóa tài khoản?\nA: Vào Tài khoản → Cài đặt → Xóa tài khoản. Hoặc liên hệ bộ phận hỗ trợ.\n\n--------------------------------------------------------------------------------\n\n7.2. VỀ ĐẶT PHÒNG\n--------------------------------------------------------------------------------\n\nQ: Tôi có thể hủy đặt phòng không?\nA: Có. Tùy theo chính sách hủy của từng cơ sở. Xem chi tiết chính sách trước \n   khi đặt.\n\nQ: Tôi đặt nhầm ngày thì phải làm sao?\nA: Liên hệ ngay với chủ cơ sở qua tính năng "Liên hệ" hoặc hotline hỗ trợ \n   để được xử lý.\n\nQ: Mã đặt phòng ở đâu?\nA: Sau khi đặt thành công, mã sẽ hiển thị trên màn hình, trong email xác nhận \n   và trong mục "Chuyến đi".\n\nQ: Tôi có thể đặt phòng cho người khác không?\nA: Có. Khi đặt phòng, bạn có thể ghi thông tin người ở vào phần yêu cầu đặc biệt.\n\nQ: Thanh toán thất bại nhưng tiền đã bị trừ?\nA: Liên hệ ngay hotline hỗ trợ với mã giao dịch để được kiểm tra và hoàn tiền.\n\nQ: Tôi có thể đặt nhiều phòng cùng lúc không?\nA: Có. Chọn số lượng phòng khi đặt.\n\nQ: Giá phòng đã bao gồm thuế chưa?\nA: Giá hiển thị chưa bao gồm thuế và phí. Tổng chi phí cuối cùng sẽ hiển thị \n   trước khi thanh toán.'),
#  Document(id='6965aa4e-35d5-4a46-a406-0eb49fb85b3c', metadata={'source': 'TÀI LIỆU HƯỚNG DẪN APP CHILLSTAY.txt'}, page_content='Q: Làm sao để xóa tài khoản?\nA: Vào Tài khoản → Cài đặt → Xóa tài khoản. Hoặc liên hệ bộ phận hỗ trợ.\n\n--------------------------------------------------------------------------------\n\n7.2. VỀ ĐẶT PHÒNG\n--------------------------------------------------------------------------------\n\nQ: Tôi có thể hủy đặt phòng không?\nA: Có. Tùy theo chính sách hủy của từng cơ sở. Xem chi tiết chính sách trước \n   khi đặt.\n\nQ: Tôi đặt nhầm ngày thì phải làm sao?\nA: Liên hệ ngay với chủ cơ sở qua tính năng "Liên hệ" hoặc hotline hỗ trợ \n   để được xử lý.\n\nQ: Mã đặt phòng ở đâu?\nA: Sau khi đặt thành công, mã sẽ hiển thị trên màn hình, trong email xác nhận \n   và trong mục "Chuyến đi".\n\nQ: Tôi có thể đặt phòng cho người khác không?\nA: Có. Khi đặt phòng, bạn có thể ghi thông tin người ở vào phần yêu cầu đặc biệt.\n\nQ: Thanh toán thất bại nhưng tiền đã bị trừ?\nA: Liên hệ ngay hotline hỗ trợ với mã giao dịch để được kiểm tra và hoàn tiền.\n\nQ: Tôi có thể đặt nhiều phòng cùng lúc không?\nA: Có. Chọn số lượng phòng khi đặt.\n\nQ: Giá phòng đã bao gồm thuế chưa?\nA: Giá hiển thị chưa bao gồm thuế và phí. Tổng chi phí cuối cùng sẽ hiển thị \n   trước khi thanh toán.')]

# %% [raw]
# # Retrive tool

# %%
from pydantic import BaseModel, Field
from typing import Type, Optional
from langchain.tools import BaseTool
from langchain.callbacks.manager import (
    CallbackManagerForToolRun,
)

# %%
class RetriveInput(BaseModel):
  query: str = Field("", description="Search query string entered by the user")

# %%
class RetrieveTool(BaseTool):
  name: str = 'chillstay_knowledge_base'
  description: str = """Công cụ này chứa toàn bộ kiến thức về ứng dụng Chillstay.
    Sử dụng công cụ này khi người dùng hỏi về:
    - Hướng dẫn đăng ký, đăng nhập
    - Cách đặt phòng, tìm kiếm
    - Chính sách thanh toán, hủy phòng
    - Các tính năng của app
    - Xử lý lỗi
    
    LUÔN sử dụng công cụ này ĐẦU TIÊN khi hỏi về Chillstay."""
    
  args_schema: Type[BaseModel] = RetriveInput
  return_direct: bool = False

  _vector_store: Type[Chroma]
  _k: int

  def __init__(self, vectorstore, **kwargs) -> None:
    super().__init__(**kwargs)
    self._vector_store = vectorstore
    self._k = kwargs.get("k", 4)

  def _run(
      self,
      query: str,
      run_manager: Optional[CallbackManagerForToolRun] = None,
  ) -> str:
    results = self._vector_store.similarity_search(query, k=self._k)
    documents = [doc.page_content for doc in results]

    return "\n\n".join(documents)

# %%
chillstay_tool = RetrieveTool(vectorstore=vectorstore, k=4)

print(tool.invoke({"query": "hướng dẫn dùng app"}))
# Out:
# Bước 4: Chọn "Thanh toán"
# - Xác nhận thông tin và thanh toán
# - Hệ thống xử lý giao dịch
#
# Bước 5: Nhận xác nhận
# - Sau khi thanh toán thành công:
#   + Bạn nhận mã đặt phòng
#   + Email xác nhận được gửi đến hộp thư
#   + Thông báo trong ứng dụng
#
# LƯU Ý:
# ✓ Kiểm tra kỹ thông tin trước khi thanh toán
# ✓ Lưu mã đặt phòng để check-in
# ✓ Đọc kỹ chính sách hủy phòng
#
# LỖI THƯỜNG GẶP:
# - "Không đủ phòng trống": Phòng vừa được đặt hết, chọn loại phòng khác
# - "Giá phòng vừa được cập nhật": Xác nhận lại giá mới
# - "Thanh toán không thành công": Kiểm tra thông tin thẻ hoặc số dư
#
# --------------------------------------------------------------------------------
#
# 3.7. LIÊN HỆ CHỦ CƠ SỞ
# --------------------------------------------------------------------------------
#
# CÁCH GỬI TIN NHẮN:
#
# Bước 1: Tại trang chi tiết cơ sở, chọn "Liên hệ chủ cơ sở"
#
# Bước 2: Điền thông tin
# - Tiêu đề: Nội dung ngắn gọn về câu hỏi
# - Nội dung: Chi tiết câu hỏi của bạn
#
# Bước 3: Chọn "Gửi"
#
# Bước 4: Chờ phản hồi
# - Chủ cơ sở sẽ trả lời qua thông báo
# - Bạn có thể xem tin nhắn trong phần "Tài khoản"
#
# LƯU Ý:
# ✓ Nội dung lịch sự, rõ ràng
# ✓ Tránh spam: Giới hạn gửi tin nhắn liên tục (tối đa mỗi 10 phút)
# ✓ Không gửi nội dung không phù hợp
#
# Q: Làm sao để xóa tài khoản?
# A: Vào Tài khoản → Cài đặt → Xóa tài khoản. Hoặc liên hệ bộ phận hỗ trợ.
#
# --------------------------------------------------------------------------------
#
# 7.2. VỀ ĐẶT PHÒNG
# --------------------------------------------------------------------------------
#
# Q: Tôi có thể hủy đặt phòng không?
# A: Có. Tùy theo chính sách hủy của từng cơ sở. Xem chi tiết chính sách trước
#    khi đặt.
#
# Q: Tôi đặt nhầm ngày thì phải làm sao?
# A: Liên hệ ngay với chủ cơ sở qua tính năng "Liên hệ" hoặc hotline hỗ trợ
#    để được xử lý.
#
# Q: Mã đặt phòng ở đâu?
# A: Sau khi đặt thành công, mã sẽ hiển thị trên màn hình, trong email xác nhận
#    và trong mục "Chuyến đi".
#
# Q: Tôi có thể đặt phòng cho người khác không?
# A: Có. Khi đặt phòng, bạn có thể ghi thông tin người ở vào phần yêu cầu đặc biệt.
#
# Q: Thanh toán thất bại nhưng tiền đã bị trừ?
# A: Liên hệ ngay hotline hỗ trợ với mã giao dịch để được kiểm tra và hoàn tiền.
#
# Q: Tôi có thể đặt nhiều phòng cùng lúc không?
# A: Có. Chọn số lượng phòng khi đặt.
#
# Q: Giá phòng đã bao gồm thuế chưa?
# A: Giá hiển thị chưa bao gồm thuế và phí. Tổng chi phí cuối cùng sẽ hiển thị
#    trước khi thanh toán.
#
# Bước 2: Xem thông tin các loại phòng
# Mỗi loại phòng hiển thị:
# - Hình ảnh phòng
# - Tên loại phòng
# - Diện tích và số người
# - Tiện nghi trong phòng
# - Giá mỗi đêm
# - Số phòng còn trống
#
# Bước 3: Điều chỉnh thông tin đặt phòng (nếu cần)
# - Ngày check-in / check-out
# - Số phòng
# - Số khách
#
# Bước 4: Chọn "Đặt phòng" ở loại phòng bạn muốn
#
# LƯU Ý:
# ✓ Phòng có nhãn "Đã hết" không thể đặt
# ✓ Giá có thể thay đổi theo ngày và chương trình khuyến mãi
#
# --------------------------------------------------------------------------------
#
# 3.6. ĐẶT PHÒNG
# --------------------------------------------------------------------------------
#
# CÁCH ĐẶT PHÒNG:
#
# Bước 1: Sau khi chọn "Đặt phòng", kiểm tra thông tin
# - Thời gian lưu trú: Check-in / Check-out
# - Loại phòng đã chọn
# - Số lượng phòng
# - Số lượng khách
# - Yêu cầu đặc biệt: Ghi chú thêm (nếu có)
#
# Bước 2: Chọn phương thức thanh toán
# - Chọn thẻ đã lưu
# - Hoặc thêm phương thức thanh toán mới
#
# Bước 3: Xem tổng chi phí
# - Giá phòng × số đêm
# - Phí dịch vụ (nếu có)
# - Thuế
# - Giảm giá (nếu có mã ưu đãi)
# - Tổng thanh toán
#
# Bước 4: Chọn "Thanh toán"
# - Xác nhận thông tin và thanh toán
# - Hệ thống xử lý giao dịch
#
# SAU KHI HOÀN TẤT CHUYẾN ĐI:
#
# Bước 1: Nhận thông báo "Viết đánh giá"
# - Sau khi check-out, hệ thống gửi thông báo
# - Hoặc vào "Chuyến đi" → Chọn đơn đã hoàn thành → "Viết đánh giá"
#
# Bước 2: Điền thông tin đánh giá
# - Chọn số sao: 1 sao (kém) đến 5 sao (xuất sắc)
# - Viết nội dung: Chia sẻ trải nghiệm của bạn
# - Thêm ảnh: Tải lên ảnh (tùy chọn)
#
# Bước 3: Chọn "Gửi"
# - Đánh giá được lưu và hiển thị công khai
#
# LƯU Ý:
# ✓ Mỗi đơn đặt phòng chỉ được đánh giá 1 lần
# ✓ Đánh giá phải chọn ít nhất số sao
# ✓ Nội dung đánh giá lịch sự, không có từ ngữ không phù hợp
#
# ================================================================================
# 6. XỬ LÝ LỖI THƯỜNG GẶP
# ================================================================================
#
# 6.1. LỖI ĐĂNG KÝ / ĐĂNG NHẬP
# --------------------------------------------------------------------------------
#
# "Email không đúng định dạng"
# → Kiểm tra lại email, đảm bảo có @ và tên miền (vd: example@gmail.com)
#
# "Email đã được sử dụng"
# → Email này đã có tài khoản, vui lòng đăng nhập hoặc dùng email khác
#
# "Mật khẩu không khớp"
# → Mật khẩu và xác nhận mật khẩu phải giống nhau
#
# "Mật khẩu yếu"
# → Mật khẩu cần tối thiểu 8 ký tự, có chữ hoa, chữ thường và số

# %% [markdown]
# # Search web tool

# %%
if "TAVILY_API_KEY" not in os.environ:
    os.environ["TAVILY_API_KEY"] = getpass.getpass("Enter API key:")

# %%
from langchain_tavily import TavilySearch

# %%
search_web_tool = TavilySearch(
    max_results=2,
    topic = "general", # news, finance
)

# %%
search_web_tool.invoke({"query" : "Gía xăng Việt Nam này 17/10/2025"})
# Out:
# {'query': 'Gía xăng Việt Nam này 17/10/2025',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://baomoi.com/gia-xang-dau-hom-nay-17-10-2025-gia-dau-the-gioi-duy-tri-on-dinh-c53511874.epi',
#    'title': 'Giá xăng dầu hôm nay 17/10/2025: giá dầu thế giới duy trì ổn định',
#    'content': 'Tại kỳ điều hành chiều 16/10, giá xăng E5 RON92 tăng 88 đồng/lít, không cao hơn 19.226 đồng/lít. Giá xăng RON95 tăng 174 đồng/lít, không cao hơn',
#    'score': 0.8116913,
#    'raw_content': None},
#   {'url': 'https://thanhnien.vn/gia-xang-dau-hom-nay-17102025-giam-phien-thu-3-lien-tiep-185251017084843985.htm',
#    'title': 'Giá xăng dầu hôm nay 17.10.2025: Giảm phiên thứ 3 liên tiếp',
#    'content': 'Giá xăng dầu hôm nay 17.10.2025: Giảm phiên thứ 3 liên tiếp-. Giá xăng trong nước tăng nhẹ từ chiều hôm qua. ẢNH: NHẬT THỊNH. Các nhà phân tích',
#    'score': 0.7783298,
#    'raw_content': None}],
#  'response_time': 0.0,
#  'request_id': 'bc7beb2b-275c-48f2-8af7-0529db3f9c14'}

# %%
from langgraph.prebuilt import create_react_agent

# %%
agent = create_react_agent(llm, [chillstay_tool, search_web_tool])

ser_input = "Giới thiệu về Einstein"

# stream
for step in agent.stream(
    {"messages": [{"role": "user", "content": user_input}]},
    stream_mode="values"
):
    # tuỳ agent/step structure, step['messages'] có thể là list of Message objects
    step['messages'][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Giới thiệu về Einstein
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search (954030c4-3e1f-4f2d-a1d3-b27bb572ad43)
#  Call ID: 954030c4-3e1f-4f2d-a1d3-b27bb572ad43
#   Args:
#     query: Albert Einstein
# ================================= Tool Message =================================
# Name: tavily_search
#
# {"query": "Albert Einstein", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://en.wikipedia.org/wiki/Albert_Einstein", "title": "Albert Einstein - Wikipedia", "content": "Albert Einstein (14 March 1879 – 18 April 1955) was a German-born theoretical physicist best known for developing the theory of relativity. Einstein also made", "score": 0.94174546, "raw_content": null}, {"url": "https://www.britannica.com/biography/Albert-Einstein", "title": "Albert Einstein | Biography, Education, Discoveries, & Facts", "content": "# Albert Einstein ### What did Albert Einstein do? Albert Einstein was a famous physicist. ### What is Albert Einstein known for? ### What influence did Albert Einstein have on science? ### What was Albert Einstein’s family like? ### How did Albert Einstein die? **Albert Einstein** (born March 14, 1879, Ulm, Württemberg, Germany—died April 18, 1955, Princeton, New Jersey, U.S.) was a German-born physicist who developed the special and general theories of relativity and won the Nobel Prize for Physics in 1921 for his explanation of the photoelectric effect. \"Albert Einstein\". * Space.com - Albert Einstein: His life, theories and impact on science * Albert Einstein - Children's Encyclopedia (Ages 8-11) * Albert Einstein - Student Encyclopedia (Ages 11 and up)", "score": 0.77261686, "raw_content": null}], "response_time": 0.72, "request_id": "b705ea0b-ffc2-4058-b04e-3f5de2d05593"}
# ================================== Ai Message ==================================
#
# Albert Einstein (1879 – 1955) là một nhà vật lý lý thuyết người Đức, nổi tiếng nhất với việc phát triển thuyết tương đối. Ông cũng có những đóng góp quan trọng khác cho vật lý lượng tử và đã đoạt giải Nobel Vật lý năm 1921 cho công trình giải thích hiệu ứng quang điện.

# %%
result = agent.invoke({"messages": [{"role": "user", "content": user_input}]})
print(result['messages'][-1].content)
# Out:
# Albert Einstein (1879 – 1955) là một nhà vật lý lý thuyết người Đức, nổi tiếng nhất với việc phát triển thuyết tương đối. Ông cũng đã có những đóng góp quan trọng khác cho vật lý, bao gồm giải thích hiệu ứng quang điện, và đã được trao giải Nobel Vật lý năm 1921.

# %% [markdown]
# # Connect firebase

# %%
def initialize_firebase(service_account_path):
    """
    Khởi tạo Firebase Admin SDK
    service_account_path: đường dẫn đến file JSON credentials từ Firebase Console
    """
    try:
        if not firebase_admin._apps:
            cred = credentials.Certificate(service_account_path)
            firebase_admin.initialize_app(cred)
        db = firestore.client()
        print("✓ Firebase đã được khởi tạo thành công!")
        return db
    except Exception as e:
        print(f"✗ Lỗi khởi tạo Firebase: {e}")
        return None

# %% [markdown]
# # UI Chatbot

# %%
def chat(user_message, history):
    if history is None:
        history = []
    
    messages = history.copy()
    messages.append({"role": "user", "content": user_message})
    
    try:
        result = agent.invoke({"messages": messages})
        bot_reply = result['messages'][-1].content
        
        history.append({"role": "user", "content": user_message})
        history.append({"role": "assistant", "content": bot_reply})
        
        return "", history
    except Exception as e:
        error_msg = f"Lỗi: {str(e)}"
        history.append({"role": "user", "content": user_message})
        history.append({"role": "assistant", "content": error_msg})
        return "", history

# %%
import gradio as gr

# %%
with gr.Blocks() as demo:
  gr.Markdown("Chatbot private")
  chatbot = gr.Chatbot(type="messages")
  with gr.Row():
    txt = gr.Textbox(
        show_label=False,
        placeholder="Nhập tin nhắn..."
    )
  txt.submit(chat, [txt, chatbot], [txt, chatbot])

demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * Running on public URL: https://ee54f7857444591ae3.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ee54f7857444591ae3.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
